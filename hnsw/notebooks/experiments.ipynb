# %%
import pandas as pd
import numpy as np
from pathlib import Path

from hnsw.utils import SIFT1MLoader

sift1m_dir = Path("/home/kldell54304/personal/graph-search-lab/data/sift1m/sift")

loader = SIFT1MLoader(sift1m_dir=sift1m_dir)
points = loader.load_sift1m_base()
query = points[0:2]

points = points[1:11]

np.sqrt(np.sum(np.square(points - query[:, np.newaxis]), 2)).shape
# Out:
# (2, 10)
